# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([10**2, 10**2.5, 10**3, 10**3.5,10**4])
# Figure 1: Normalized SHD
# Data for Normalized SHD
normalized_shd_golem_ev = [11, 2.6, 4e-1, 2e-1, 8e-2]
normalized_shd_golem_ev_l1 = [8e-1, 1e-2, 8e-3, 6e-3, 4e-3]
# normalized_shd_golem_ev = []
# normalized_shd_golem_ev_l1 = []
# normalized_shd_golem_ev_plain = []


# Figure 2: TPR
# Data for TPR
tpr_golem_ev = np.array([0.5, 0.6, 0.55, 0.57, 0.51])
tpr_golem_ev_l1 = np.array([0.6, 0.81, 0.95, 1, 1])
# tpr_golem_ev = []
# tpr_golem_ev_l1 = []
# tpr_golem_ev_plain = []

# Figure 3: h(B)
# Data for h(B)
hb_golem_ev =[6e-1, 3e-3, 1.5e-2, 6.2e-2, 5.3e-2]
hb_golem_ev_l1 = [3e-1, 1e-2, 1e-3, 2e-3, 3e-4]
# hb_golem_ev = []
# hb_golem_ev_l1 = []
# hb_golem_ev_plain = []

frob_norm = [8e-1, 1e-1, 2.5e-1, 2e-1, 1.6e-1]
frob_norm_l2 = [8e-2, 1e-2, 2.5e-3, 2e-3, 2.2e-3]

fig, axs = plt.subplots(2, 2, figsize=(18, 5))

# Plot Normalized SHD
axs[0][0].set_xscale('log')
axs[0][0].set_yscale('log')
#axs[0][0].plot(x, normalized_shd_golem_ev,  marker='o', markerfacecolor='None', markersize=12, linestyle='-', color='blue', label='GOLEM')
axs[0][0].plot(x, normalized_shd_golem_ev_l1, marker='v', markerfacecolor='None', markersize=12, linestyle='-', color='orange', label='SSM-Lin')
# axs[0].set_title('Normalized SHD')
axs[0][0].set_xlabel('n (Sample size)', fontname='Times New Roman', fontsize=10)
axs[0][0].set_ylabel('Normalized SHD' , fontname='Times New Roman', fontsize=10)
axs[0][0].set_yticks([10**-3, 10**-2, 10**-1, 10**0, 10**1], [r'$10^{-3}$', r'$10^{-2}$', '$10^{-1}$', '$10^0$', '$10^1$'])
axs[0][0].set_ylim(10**-3, 10**2) 
axs[0][0].grid(True, which='major', linestyle='--', color='gray')
axs[0][0].grid(True, which='minor', linestyle='', color='gray')

# Plot TPR
axs[0][1].set_xscale('log')
#axs[0][1].plot(x, tpr_golem_ev, marker='o', markerfacecolor='None', markersize=12, linestyle='-', color='blue', label='GOLEM')
axs[0][1].plot(x, tpr_golem_ev_l1, marker='v', markerfacecolor='None', markersize=12, linestyle='-', color='orange', label='SSM-Lin')
# axs[1].set_title('TPR')
axs[0][1].set_xlabel('n (Sample size)', fontname='Times New Roman', fontsize=10)
axs[0][1].set_ylabel('TPR' , fontname='Times New Roman', fontsize=10)
axs[0][1].set_yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1.0])
axs[0][1].set_ylim(0.48, 1.1)
axs[0][1].grid(True, which='major', linestyle='--', color='gray')
axs[0][1].grid(True, which='minor', linestyle='', color='gray')

# Plot h(B)
axs[1][0].set_xscale('log')
axs[1][0].set_yscale('log')
#axs[1][0].plot(x, hb_golem_ev, marker='o', markerfacecolor='None', markersize=12, linestyle='-', color='blue', label='GOLEM')
axs[1][0].plot(x, hb_golem_ev_l1, marker='v', markerfacecolor='None', markersize=12, linestyle='-', color='orange', label='SSM-Lin')
# axs[2].set_title('h(B)')
axs[1][0].set_xlabel('n (Sample size)', fontname='Times New Roman', fontsize=10)
axs[1][0].set_ylabel('h(B)' , fontname='Times New Roman', fontsize=10)
axs[1][0].set_yticks([1e-3, 1e-2, 1e-1, 1, 10], ['$10^{-3}$','$10^{-2}$', '$10^{-1}$', '$10^0$', '$10^1$'])
axs[1][0].grid(True, which='major', linestyle='--', color='gray')
axs[1][0].grid(True, which='minor', linestyle='', color='gray')

# Plot avg l2
axs[1][1].set_xscale('log')
axs[1][1].set_yscale('log')
#axs[1][1].plot(x, frob_norm, marker='o', markerfacecolor='None', markersize=12, linestyle='-', color='blue', label='GOLEM')
axs[1][1].plot(x, frob_norm_l2, marker='v', markerfacecolor='None', markersize=12, linestyle='-', color='orange', label='SSM-Lin')
# axs[2].set_title('h(B)')
axs[1][1].set_xlabel('n (Sample size)', fontname='Times New Roman', fontsize=10)
axs[1][1].set_ylabel('Frobenius Norm' , fontname='Times New Roman', fontsize=10)
axs[1][1].set_yticks([1e-3, 1e-2, 1e-1, 1, 10], ['$10^{-3}$','$10^{-2}$', '$10^{-1}$', '$10^0$', '$10^1$'])
axs[1][1].grid(True, which='major', linestyle='--', color='gray')
axs[1][1].grid(True, which='minor', linestyle='', color='gray')


# fig.legend()
handles, labels = axs[0][0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.1))
plt.show()
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([10**2, 10**2.5, 10**3, 10**3.5,10**4])
# Figure 1: Normalized SHD
# Data for Normalized SHD
normalized_shd_golem_ev = [11, 2.6, 4e-1, 2e-1, 8e-2]
normalized_shd_golem_ev_l1 = [8e-1, 1e-2, 8e-3, 6e-3, 4e-3]
# normalized_shd_golem_ev = []
# normalized_shd_golem_ev_l1 = []
# normalized_shd_golem_ev_plain = []


# Figure 2: TPR
# Data for TPR
tpr_golem_ev = np.array([0.5, 0.6, 0.55, 0.57, 0.51])
tpr_golem_ev_l1 = np.array([0.6, 0.81, 0.95, 1, 1])
# tpr_golem_ev = []
# tpr_golem_ev_l1 = []
# tpr_golem_ev_plain = []

# Figure 3: h(B)
# Data for h(B)
hb_golem_ev =[6e-1, 3e-3, 1.5e-2, 6.2e-2, 5.3e-2]
hb_golem_ev_l1 = [3e-1, 1e-2, 1e-3, 2e-3, 3e-4]
# hb_golem_ev = []
# hb_golem_ev_l1 = []
# hb_golem_ev_plain = []

frob_norm = [8e-1, 1e-1, 2.5e-1, 2e-1, 1.6e-1]
frob_norm_l2 = [8e-2, 1e-2, 2.5e-3, 2e-3, 2.2e-3]

fig, axs = plt.subplots(2, 2, figsize=(18, 5))

# Plot Normalized SHD
axs[0][0].set_xscale('log')
axs[0][0].set_yscale('log')
axs[0][0].plot(x, normalized_shd_golem_ev,  marker='o', markerfacecolor='None', markersize=12, linestyle='-', color='blue', label='GOLEM')
axs[0][0].plot(x, normalized_shd_golem_ev_l1, marker='v', markerfacecolor='None', markersize=12, linestyle='-', color='orange', label='TV-GOLEM')
# axs[0].set_title('Normalized SHD')
axs[0][0].set_xlabel('n (Sample size)', fontname='Times New Roman', fontsize=10)
axs[0][0].set_ylabel('Normalized SHD' , fontname='Times New Roman', fontsize=10)
axs[0][0].set_yticks([10**-3, 10**-2, 10**-1, 10**0, 10**1], [r'$10^{-3}$', r'$10^{-2}$', '$10^{-1}$', '$10^0$', '$10^1$'])
axs[0][0].set_ylim(10**-3, 10**2) 
axs[0][0].grid(True, which='major', linestyle='--', color='gray')
axs[0][0].grid(True, which='minor', linestyle='', color='gray')

# Plot TPR
axs[0][1].set_xscale('log')
axs[0][1].plot(x, tpr_golem_ev, marker='o', markerfacecolor='None', markersize=12, linestyle='-', color='blue', label='GOLEM')
axs[0][1].plot(x, tpr_golem_ev_l1, marker='v', markerfacecolor='None', markersize=12, linestyle='-', color='orange', label='TV-GOLEM')
# axs[1].set_title('TPR')
axs[0][1].set_xlabel('n (Sample size)', fontname='Times New Roman', fontsize=10)
axs[0][1].set_ylabel('TPR' , fontname='Times New Roman', fontsize=10)
axs[0][1].set_yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1.0])
axs[0][1].set_ylim(0.48, 1.1)
axs[0][1].grid(True, which='major', linestyle='--', color='gray')
axs[0][1].grid(True, which='minor', linestyle='', color='gray')

# Plot h(B)
axs[1][0].set_xscale('log')
axs[1][0].set_yscale('log')
axs[1][0].plot(x, hb_golem_ev, marker='o', markerfacecolor='None', markersize=12, linestyle='-', color='blue', label='GOLEM')
axs[1][0].plot(x, hb_golem_ev_l1, marker='v', markerfacecolor='None', markersize=12, linestyle='-', color='orange', label='TV-GOLEM')
# axs[2].set_title('h(B)')
axs[1][0].set_xlabel('n (Sample size)', fontname='Times New Roman', fontsize=10)
axs[1][0].set_ylabel('h(B)' , fontname='Times New Roman', fontsize=10)
axs[1][0].set_yticks([1e-3, 1e-2, 1e-1, 1, 10], ['$10^{-3}$','$10^{-2}$', '$10^{-1}$', '$10^0$', '$10^1$'])
axs[1][0].grid(True, which='major', linestyle='--', color='gray')
axs[1][0].grid(True, which='minor', linestyle='', color='gray')

# Plot avg l2
axs[1][1].set_xscale('log')
axs[1][1].set_yscale('log')
axs[1][1].plot(x, frob_norm, marker='o', markerfacecolor='None', markersize=12, linestyle='-', color='blue', label='GOLEM')
axs[1][1].plot(x, frob_norm_l2, marker='v', markerfacecolor='None', markersize=12, linestyle='-', color='orange', label='TV-GOLEM')
# axs[2].set_title('h(B)')
axs[1][1].set_xlabel('n (Sample size)', fontname='Times New Roman', fontsize=10)
axs[1][1].set_ylabel('Frobenius Norm' , fontname='Times New Roman', fontsize=10)
axs[1][1].set_yticks([1e-3, 1e-2, 1e-1, 1, 10], ['$10^{-3}$','$10^{-2}$', '$10^{-1}$', '$10^0$', '$10^1$'])
axs[1][1].grid(True, which='major', linestyle='--', color='gray')
axs[1][1].grid(True, which='minor', linestyle='', color='gray')


# fig.legend()
handles, labels = axs[0][0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.1))
plt.show()
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.

# %%
x = np.logspace(2, 4, num=10)

y1 = []
y2 = []
y3 = []


plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='o', markerfacecolor='None', markersize=12, linestyle='-', color='blue', label='GOLEM-EV')
plt.plot(x, y2, marker='^', markerfacecolor='None', markersize=12, linestyle='-', color='orange', label='GOLEM-EV-L1')
plt.plot(x, y3, marker='D', markerfacecolor='None', markersize=12, linestyle='-', color='green', label='GOLEM-EV-Plain')


plt.xscale('log')
plt.yscale('log')

plt.yticks([10**1, 10**7, 10**13, 10**19, 10**25], ['$10^{1}$', '$10^{7}$', '$10^{13}$', '$10^{19}$','$10^{25}$'])

plt.xlabel('n (Sample size)', fontsize=20)
plt.ylabel(r'$h(B)$' , fontsize=20)

plt.ylim(1, 10**25) 

# plt.legend()


plt.grid(True, which='major', linestyle='--', color='gray')
plt.grid(True, which='minor', linestyle='', color='gray')  # No grid for minor ticks


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 9
#       5 y3 = []
#       8 plt.figure(figsize=(10, 6))
# ----> 9 plt.plot(x, y1, marker='o', markerfacecolor='None', markersize=12, linestyle='-', color='blue', label='GOLEM-EV')
#      10 plt.plot(x, y2, marker='^', markerfacecolor='None', markersize=12, linestyle='-', color='orange', label='GOLEM-EV-L1')
#      11 plt.plot(x, y3, marker='D', markerfacecolor='None', markersize=12, linestyle='-', color='green', label='GOLEM-EV-Plain')
#
# File ~/.conda/envs/minghao_env/lib/python3.12/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~/.conda/envs/minghao_env/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File ~/.conda/envs/minghao_env/lib/python3.12/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/.conda/envs/minghao_env/lib/python3.12/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (0,)
